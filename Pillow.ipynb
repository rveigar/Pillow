# %% [markdown]
# <a href="https://colab.research.google.com/github/rveigar/Pillow/blob/main/Pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install Pillow
#para mostrar a imagem no colab usar o IPython.display
from PIL import Image
from IPython.display import display # to display images
from google.colab import files

#im = files.upload()
#print(im)
im=Image.open('selfie2.jpg')
display(im.rotate(45))
#display(im)

# %%
#!pip install Pillow
#para mostrar a imagem no colab usar o IPython.display
from PIL import Image
from IPython.display import display # to display images
from google.colab import files

#im = files.upload()
#print(im)
im2=Image.open('selfie2.jpg')
#display(im.rotate(45))
display(im2)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x1600 at 0x7FC5A97D6750>

# %%
#!pip install Pillow
#para mostrar a imagem no colab usar o IPython.display
from PIL import Image
from IPython.display import display # to display images
from google.colab import files

size=(256,256)

#im = files.upload()
#print(im)
im2=Image.open('selfie2.jpg')
im2.thumbnail(size)
im2.save("thumbnail.jpg", "JPEG")

#display(im.rotate(45))
display(Image.open('thumbnail.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=144x256 at 0x7FC5A97D9B10>

# %%
from PIL import Image
from IPython.display import display # to display images
with Image.open("IMG_5765.JPG") as im:
  display(im.rotate(45))
# Out:
# <PIL.Image.Image image mode=RGB size=720x720 at 0x7FC5A97BCF90>

# %%
# Create JPEG thumbnails
from PIL import Image
from IPython.display import display # to display images

import glob, os
# thumbnail
size = 128, 128
for infile in glob.glob("*.JPG"):
    file, ext = os.path.splitext(infile)
    with Image.open(infile) as im:
        im.thumbnail(size)
        im.save(file + "_thumbnail.jpg", "JPEG")
        a= (file + ".thumbnail")
display(Image.open(a))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-23-08ecef91b572> in <module>()
#      12         im.save(file + "_thumbnail.jpg", "JPEG")
#      13         a= (file + ".thumbnail")
# ---> 14 display(Image.open(a))
#
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: 'IMG_5765.thumbnail'

# %%
from PIL import Image
size = 128, 128

image0=Image.open('P1030911.JPG','r')
image0.thumbnail(size)
image0
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=128x96 at 0x7F4E126CB590>

# %%
# para não precisar usar o IPython, usar somente a variavel [im] para mostrar a imagem e não usar [im.show()]
from PIL import Image
im = Image.open("IMG_5765.JPG")
print(im.format, im.size, im.mode)
im
# Out:
# JPEG (720, 720) RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=720x720 at 0x7FA0B3E45050>

# %%
from PIL import ImageEnhance
im = Image.open("IMG_5765.JPG")
enh = ImageEnhance.Contrast(im)
a=enh.enhance(1.3).show("30% more contrast")
a
